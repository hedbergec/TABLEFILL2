// %% [markdown]
// Eric Hedberg
//
// # Introduction
//
// The purpose of the `tablefill` series of `Stata` `ado` files is to run survey statistics such as means, totals, and proportions and to populate simple cross tables with the results. The program is stored in the files in the `tablefill` directory.
//
// The key to making it work is that the `using` data must have variable and value labels which can be matched to the variable and value tables of the `using` table shell. The table shell can use returns and other special characters that are not going to be found in the variable and value labels, but the case insensitive characters must be unique across all labels in the variables used and match the table shell.
//
// # Syntax
//
// The syntax of the `tablefill` command is as follows
//
// `tablefill using [`_excelfile_`] [if], sheet([`_sheetname_`]) statistics(`_statspec_`) domainvars(`_varlist_`) savefolder(`_path_`) titlecell(`_titlecell_`) title(`_titlestring_`) [raw] [noisily]`
//
// where
//
// - _excelfile_ is the table shell
// - `if` is to select which rows to use for analysis
// - _sheetname_ is the sheet in the table shell file to populate
// - _varlist_ are all the variables associated with row or columns in the table shell
// - _path_ is a path to store the estimation results
// - _titlecell_ is the Excel cell to put the title, e.g. A1
// - _titlestring_ is the Table title to put in _titlecell_
// - use `raw` to avoid supression routines (good idea for descriptive stats)
// - use `nosily` if you want to see print-outs of the estimations in `results viewer`. This will produce *a lot* of output.
//
// The _statspec_ is a series of stat commands seperated by a single `|`. A single stat command has the following syntax
//
// [`total|mean|proportion] [`_var_]`, [row|col] point(`_pointcols_`) [se(`_secols_`)] [note(`_notecols_`)] factor(`_factorexpr_`) bformat(`_bfmt_`) seformat(`_sefmt_`)`
//
// where you can have either totals or means of a single variable _var_ or a porportion, and the options detail which columns to put the point estimate, standard errors, and notes for unreliable estiamtes. The estimates and standard errors can be altered by a _factorexpr_ such as `*100` for changing proportions to percents or `*0.001` for changing raw counts to thousands. After this factor is applied, the results are formatted into strings using stata format expression for the point estimates (_bfmt_) and standard errors (_sefmt_).
//
// # Descriptive Example
//
// Let's run totals and column percentages to populate this table saved in `shell.xlsx`
//
// ![alt text](pics/ex1.png "Example Excel File")
//
//
// The data have been cleaned as are stored in `input_data.dta`
//
// ## Step 1 Load the Program
//
// First, we need to load the tablefill program. Utill this is ready and sent to SSC, you need to point `Stata` to the right directory. Here, the program folder is saved in the working directory, so we use `adopath` to add the folder

// %%
adopath + "./tablefill"
// Out:
//   [1]  (BASE)      "/Applications/Stata/ado/base/"
//   [2]  (SITE)      "/Applications/Stata/ado/site/"
//   [3]              "."
//   [4]  (PERSONAL)  "/Users/hedbergec/Documents/Stata/ado/personal/"
//   [5]  (PLUS)      "/Users/hedbergec/Library/Application Support/Stata/ado/plus/
// > "
//   [6]  (OLDPLACE)  "~/ado/"
//   [7]              "/opt/anaconda3/lib/python3.12/site-packages/stata_kernel/ado
// > "
//   [8]              "./tablefill"

// %% [markdown]
// ## Step 2 Load the data
//
// Here we load the data into memory and create a constant variable which is used for totals

// %%
use "input_data.dta", clear
gen cons = 1

// %% [markdown]
// Note this data also has an "all" variable which is 1, but is labeled for the "Total" row and column in the shell

// %%
codebook all
// Out:
// --------------------------------------------------------------------------------
// all                                                                        Total
// --------------------------------------------------------------------------------
//
//                   Type: Numeric (double)
//                  Label: tot
//
//                  Range: [1,1]                         Units: 1
//          Unique values: 1                         Missing .: 0/38,394
//
//             Tabulation: Freq.   Numeric  Label
//                        38,394         1  Total

// %% [markdown]
// Here are the other variables we will use

// %%
set more off
codebook T0356 RACETH_T AGE_T Highest_degree ///
        TOTEXPER_rc T0104_rc URBANIC TEALEV2 ///
        secondary elementary S0285_S0287 REGION S0256
// Out:
// --------------------------------------------------------------------------------
// T0356                                                                        Sex
// --------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: sex
//
//                  Range: [1,2]                         Units: 1
//          Unique values: 2                         Missing .: 0/38,394
//
//             Tabulation: Freq.   Numeric  Label
//                        12,503         1  Male
//                        25,891         2  Female
//
// --------------------------------------------------------------------------------
// RACETH_T                                                          Race/ethnicity
// --------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: raceeth
//
//                  Range: [1,5]                         Units: 1
//          Unique values: 5                         Missing .: 0/38,394
//
//             Tabulation: Freq.   Numeric  Label
//                           940         1  American Indian/Alaska Native
//                           982         2  Asian or Pacific Islander
//                         2,350         3  Black
//                        32,470         4  White
//                         1,652         5  Hispanic
//
// --------------------------------------------------------------------------------
// AGE_T                                                                        Age
// --------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: age
//
//                  Range: [1,4]                         Units: 1
//          Unique values: 4                         Missing .: 0/38,394
//
//             Tabulation: Freq.   Numeric  Label
//                         6,085         1  Under 30
//                         8,470         2  30 to 39
//                        12,498         3  40 to 49
//                        11,341         4  50 and over
//
// --------------------------------------------------------------------------------
// Highest_degree                                             Highest degree earned
// --------------------------------------------------------------------------------
//
//                   Type: Numeric (double)
//                  Label: degre
//
//                  Range: [1,5]                         Units: 1
//          Unique values: 5                         Missing .: 0/38,394
//
//             Tabulation: Freq.   Numeric  Label
//                           105         1  Associate
//                        21,018         2  Bachelor's
//                        15,764         3  Master's
//                         1,168         4  Education Specialist
//                           339         5  Doctor's
//
// --------------------------------------------------------------------------------
// TOTEXPER_rc                                         Years of teaching experience
// --------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: TOTEXPER_rc
//
//                  Range: [1,4]                         Units: 1
//          Unique values: 4                         Missing .: 0/38,394
//
//             Tabulation: Freq.   Numeric  Label
//                         4,124         1  Less than 3
//                        10,681         2  3 to 9
//                        11,249         3  10 to 20
//                        12,340         4  Over 20
//
// --------------------------------------------------------------------------------
// T0104_rc                                                   Certification type\2\
// --------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: cert
//
//                  Range: [1,6]                         Units: 1
//          Unique values: 5                         Missing .: 0/38,394
//
//             Tabulation: Freq.   Numeric  Label
//                        33,630         1  Regular
//                         1,979         2  Probationary
//                           446         4  Provisional or temporary
//                           189         5  Waiver or emergency
//                         2,150         6  No certification
//
// --------------------------------------------------------------------------------
// URBANIC                                                            School locale
// --------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: urb
//
//                  Range: [1,3]                         Units: 1
//          Unique values: 3                         Missing .: 0/38,394
//
//             Tabulation: Freq.   Numeric  Label
//                         8,661         1  Large or mid-size central city
//                        15,124         2  Urban fringe of large or
//                                          mid-size city
//                        14,609         3  Small town/Rural
//
// --------------------------------------------------------------------------------
// TEALEV2                                                              (unlabeled)
// --------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: level
//
//                  Range: [1,2]                         Units: 1
//          Unique values: 2                         Missing .: 0/38,394
//
//             Tabulation: Freq.   Numeric  Label
//                        13,143         1  Elementary
//                        25,251         2  Secondary
//
// --------------------------------------------------------------------------------
// secondary                                                              Secondary
// --------------------------------------------------------------------------------
//
//                   Type: Numeric (double)
//                  Label: sec
//
//                  Range: [1,1]                         Units: 1
//          Unique values: 1                         Missing .: 13,143/38,394
//
//             Tabulation: Freq.   Numeric  Label
//                        25,251         1  Secondary
//                        13,143         .
//
// --------------------------------------------------------------------------------
// elementary                                                            Elementary
// --------------------------------------------------------------------------------
//
//                   Type: Numeric (double)
//                  Label: ele
//
//                  Range: [1,1]                         Units: 1
//          Unique values: 1                         Missing .: 25,251/38,394
//
//             Tabulation: Freq.   Numeric  Label
//                        13,143         1  Elementary
//                        25,251         .
//
// --------------------------------------------------------------------------------
// S0285_S0287         Percent of students eligible for free or reduced-price lunch
// --------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: lunch
//
//                  Range: [1,5]                         Units: 1
//          Unique values: 5                         Missing .: 0/38,394
//
//             Tabulation: Freq.   Numeric  Label
//                         2,583         1  0 to 5
//                         9,744         2  5 to 19
//                        13,537         3  20 to 49
//                        10,221         4  50 to 100
//                         2,309         5  School does not participate
//
// --------------------------------------------------------------------------------
// REGION                                                               U.S. Region
// --------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: region
//
//                  Range: [1,4]                         Units: 1
//          Unique values: 4                         Missing .: 0/38,394
//
//             Tabulation: Freq.   Numeric  Label
//                         5,391         1  Northeast: Connecticut, Maine,
//                                          Massachusetts, New Hampshire,
//                                          New Jersey, New York,
//                                          Pennsylvania, Rhode Island,
//                                          Vermont
//                         9,392         2  Midwest: Illinois, Indiana,
//                                          Iowa, Kansas, Michigan,
//                                          Minnesota, Missouri, Nebraska,
//                                          North Dakota, Ohio, South
//                                          Dakota, Wisconsin
//                        13,830         3  South: Alabama, Arkansas,
//                                          Delaware, District of Columbia,
//                                          Florida, Georgia, Kentucky,
//                                          Louisiana, Maryland,
//                                          Mississippi, North Carolina,
//                                          Oklahoma, South Carolina,
//                                          Tennessee, Texas, Virginia,
//                                          West Virginia
//                         9,781         4  West: Alaska, Arizona,
//                                          California, Colorado, Hawaii,
//                                          Idaho, Montana, Nevada, New
//                                          Mexico, Oregon, Utah,
//                                          Washington, Wyoming
//
// --------------------------------------------------------------------------------
// S0256                                                          Teacher vacancies
// --------------------------------------------------------------------------------
//
//                   Type: Numeric (byte)
//                  Label: vacant
//
//                  Range: [1,2]                         Units: 1
//          Unique values: 2                         Missing .: 0/38,394
//
//             Tabulation: Freq.   Numeric  Label
//                        34,113         1  No vacancies
//                         4,281         2  Vacancies

// %% [markdown]
// ## Step 3 Run the table
//
// Here is the command which uses all the variables associated with the rows and columns. Note that the variable names can be the typical ugly variable names, all that is important is the labels. Be sure to have a "Results" folder ready, too.

// %%
tablefill using "shell.xlsx", /// the shell
    sheet("Table 1") /// the sheet
    statistics( /// describe what statistics to estimate and columns
    total cons, point(B D F) ///
        factor(*0.001) bformat(%6.0fc)  ///
        | /// pipe for antoher statistic
    proportion, col p(H J L) ///
        factor(*100) bformat(%3.0f) ///
    ) ///
    domainvars( ///
        all ///
        T0356 RACETH_T AGE_T Highest_degree ///
        TOTEXPER_rc T0104_rc URBANIC TEALEV2 ///
        secondary elementary S0285_S0287 REGION S0256 ///
    ) ///
    savefolder("Results")   ///
    raw /// don't supress results based on cell counts or high SEs
    titlecell(A1) ///
    title("Table 1. Number and percentage distribution of teachers in traditional public elementary and secondary schools, by instructional level and selected teacher and school characteristics: School year 1999-2000")
// Out:
// running total commands
//
// running proportion commands
// Results/shell_populated.xlsx populated

// %% [markdown]
// In the Results folder is the populated Excel file
//
// ![alt text](pics/ex2.png "Populated Excel File")

// %% [markdown]
// # Survey Estimation Example
//
// The primary purpose of `tablefill` is to allow for fast estimation of survey tables.
//
// A more complex table would use complex survey settings to estimate weighted means and totals and associated standard errors.
//
// ![alt text](pics/ex3.png "Survey Excel File")
//
// The steps are largely the same, except we first must enter the survey settings. As `tablefill` uses `Stata`'s native survey routines, you can use `Stata`'s native survey setting framework. For example

// %%
svyset [pw = TFNLWGT] , vce(brr) brrweight(TREPWT*)
// Out:
// Sampling weights: TFNLWGT
//              VCE: brr
//              MSE: off
//      BRR weights: TREPWT1 .. TREPWT9
//      Single unit: missing
//         Strata 1: <one>
//  Sampling unit 1: <observations>
//            FPC 1: <zero>

// %% [markdown]
// We then use a similar `tablefill` command for a different shell, `shell_SVY.xlsx`, adding columns for standard errors and notes. As all results files which are created are keyed to the shell filename, we can use the same `Results` folder.

// %%
tablefill using "shell_SVY.xlsx", /// the shell
    sheet("Table 2") /// the sheet
    statistics( /// describe what statistics to estimate and columns
    total cons, point(B E H) note(C F I) se(D G J) ///
        factor(*0.001) bformat(%6.0fc) seformat(%6.1f) ///
        | /// pipe for antoher statistic
    proportion, col p(K N Q) note(L O R) se(M P S) ///
        factor(*100) bformat(%3.0f) seformat(%3.1f) ///
    ) ///
    domainvars( ///
        all ///
        T0356 RACETH_T AGE_T Highest_degree ///
        TOTEXPER_rc T0104_rc URBANIC TEALEV2 ///
        secondary elementary S0285_S0287 REGION S0256 ///
    ) ///
    savefolder("Results")   ///
    titlecell(A1) ///
    title("Table 2. Number and percentage distribution of teachers in traditional public elementary and secondary schools, by instructional level and selected teacher and school characteristics: School year 1999-2000")
// Out:
// survey settings detected
//
// running total commands
//
// running proportion commands
// Results/shell_SVY_populated.xlsx populated

// %% [markdown]
// Which saved the populated table in the `Results` folder
//
// ![alt text](pics/ex4.png "Populated Survey Excel File")

// %% [markdown]
// # Multiple Imputation Examples
//
// Here, we show how to use `tablefill` with multiple-imputation data.
//
// Below I first clear any `svyset`tings and  simulate missing data on `TOTEXER_rc` (experience) and `T0104_rc` (certification) and impute these values with the other information available using chained equations.

// %%
svyset, clear

foreach v in TOTEXPER_rc T0104_rc {
        quietly : clonevar `v'_miss =  `v' 
        quietly : replace `v'_miss = . if runiform() > .85
}

mi set wide
mi register imputed TOTEXPER_rc_miss T0104_rc_miss
mi impute chained (ologit, augment) TOTEXPER_rc_miss (mlogit, augment) T0104_rc_miss = ///
        i.Highest_degree i.T0356 i.RACETH_T i.AGE_T i.URBANIC ///
        i.S0285_S0287 i.REGION i.S0256 i.TEALEV2, add(5)
// Out:
// no; data are mi set
//     Use mi svyset to set or query these data; mi svyset has the same syntax as
//     svyset.
//
//     Perhaps you did not type svyset.  Some commands call svyset to obtain
//     information about the settings.  In that case, that command is not
//     appropriate for running directly on mi data.  Use mi extract to select the
//     data on which you want to run the command, which is probably m=0.
// r(119);
// r(119);

// %% [markdown]
// Next, to produce the simple table with the missing imputed data

// %%
tablefill using "shell_MI.xlsx", /// the shell
    sheet("Table 3") /// the sheet
    statistics( /// describe what statistics to estimate and columns
    total cons, point(B D F) ///
        factor(*0.001) bformat(%6.0fc)  ///
        | /// pipe for antoher statistic
    proportion, col p(H J L) ///
        factor(*100) bformat(%3.0f) ///
    ) ///
    domainvars( ///
        all ///
        T0356 RACETH_T AGE_T Highest_degree ///
        TOTEXPER_rc_miss T0104_rc_miss URBANIC TEALEV2 ///
        secondary elementary S0285_S0287 REGION S0256 ///
    ) ///
    savefolder("Results")   ///
    raw /// don't supress results based on cell counts or high SEs
    titlecell(A1) ///
    title("Table 3. Number and percentage distribution of teachers in traditional public elementary and secondary schools, by instructional level and selected teacher and school characteristics: School year 1999-2000")
// Out:
// 5 multiple imputations detected
//
// running total commands
//
// running proportion commands
// Results/shell_MI_populated.xlsx populated

// %% [markdown]
// Which produces a table like this
//
// ![alt text](pics/ex6.png "Populated Excel File")
//
// Next, I `mi svyset` the data since we have both multiple imputations and survey settings (note that you cannot use replicate survey estimation methods with multiple-imputed data, so typically we would also specify a PSU and Stata variable).

// %%
mi svyset [pw = TFNLWGT]
// Out:
// Sampling weights: TFNLWGT
//              VCE: linearized
//      Single unit: missing
//         Strata 1: <one>
//  Sampling unit 1: <observations>
//            FPC 1: <zero>

// %% [markdown]
// The shell is
//
// ![alt text](pics/ex7.png "Populated Excel File")
//
// and the command is

// %%
tablefill using "shell_SVY_MI.xlsx", /// the shell
    sheet("Table 4") /// the sheet
    statistics( /// describe what statistics to estimate and columns
    total cons, point(B E H) note(C F I) se(D G J) ///
        factor(*0.001) bformat(%6.0fc) seformat(%6.1f) ///
        | /// pipe for antoher statistic
    proportion, col p(K N Q) note(L O R) se(M P S) ///
        factor(*100) bformat(%3.0f) seformat(%3.1f) ///
    ) ///
    domainvars( ///
        all ///
        T0356 RACETH_T AGE_T Highest_degree ///
        TOTEXPER_rc_miss T0104_rc_miss URBANIC TEALEV2 ///
        secondary elementary S0285_S0287 REGION S0256 ///
    ) ///
    savefolder("Results")   ///
    titlecell(A1) ///
    title("Table 4. Number and percentage distribution of teachers in traditional public elementary and secondary schools, by instructional level and selected teacher and school characteristics: School year 1999-2000")
// Out:
// 5 multiple imputations detected
// mi survey settings detected
//
// running total commands
//
// running proportion commands
// Results/shell_SVY_MI_populated.xlsx populated

// %% [markdown]
// Which produces a table like this
//
// ![alt text](pics/ex8.png "Populated Excel File")

// %% [markdown]
// # What's saved?
//
// Here is list of files which are saved in the `Results` folder. This includes `ster` files which are the saved estimation results and the `dta` files are Stata data files with information about the estimates and which Excel cell they are saved in.

// %%
ls Results/, wide
// Out:
// est_prop__AGE_T_by_all_shell_MIxlsx.ster
// est_prop__AGE_T_by_all_shell_SVY_MIxlsx.ster
// est_prop__AGE_T_by_all_shell_SVYxlsx.ster
// est_prop__AGE_T_by_all_shellxlsx.ster
// est_prop__AGE_T_by_elementary_shell_MIxlsx.ster
// est_prop__AGE_T_by_elementary_shell_SVY_MIxlsx.ster
// est_prop__AGE_T_by_elementary_shell_SVYxlsx.ster
// est_prop__AGE_T_by_elementary_shellxlsx.ster
// est_prop__AGE_T_by_secondary_shell_MIxlsx.ster
// est_prop__AGE_T_by_secondary_shell_SVY_MIxlsx.ster
// est_prop__AGE_T_by_secondary_shell_SVYxlsx.ster
// est_prop__AGE_T_by_secondary_shellxlsx.ster
// est_prop__Highest_degree_by_all_shell_MIxlsx.ster
// est_prop__Highest_degree_by_all_shell_SVY_MIxlsx.ster
// est_prop__Highest_degree_by_all_shell_SVYxlsx.ster
// est_prop__Highest_degree_by_all_shellxlsx.ster
// est_prop__Highest_degree_by_elementary_shell_MIxlsx.ster
// est_prop__Highest_degree_by_elementary_shell_SVY_MIxlsx.ster
// est_prop__Highest_degree_by_elementary_shell_SVYxlsx.ster
// est_prop__Highest_degree_by_elementary_shellxlsx.ster
// est_prop__Highest_degree_by_secondary_shell_MIxlsx.ster
// est_prop__Highest_degree_by_secondary_shell_SVY_MIxlsx.ster
// est_prop__Highest_degree_by_secondary_shell_SVYxlsx.ster
// est_prop__Highest_degree_by_secondary_shellxlsx.ster
// est_prop__RACETH_T_by_all_shell_MIxlsx.ster
// est_prop__RACETH_T_by_all_shell_SVY_MIxlsx.ster
// est_prop__RACETH_T_by_all_shell_SVYxlsx.ster
// est_prop__RACETH_T_by_all_shellxlsx.ster
// est_prop__RACETH_T_by_elementary_shell_MIxlsx.ster
// est_prop__RACETH_T_by_elementary_shell_SVY_MIxlsx.ster
// est_prop__RACETH_T_by_elementary_shell_SVYxlsx.ster
// est_prop__RACETH_T_by_elementary_shellxlsx.ster
// est_prop__RACETH_T_by_secondary_shell_MIxlsx.ster
// est_prop__RACETH_T_by_secondary_shell_SVY_MIxlsx.ster
// est_prop__RACETH_T_by_secondary_shell_SVYxlsx.ster
// est_prop__RACETH_T_by_secondary_shellxlsx.ster
// est_prop__S0285_S0287_by_all_shell_MIxlsx.ster
// est_prop__S0285_S0287_by_all_shell_SVY_MIxlsx.ster
// est_prop__S0285_S0287_by_all_shell_SVYxlsx.ster
// est_prop__S0285_S0287_by_all_shellxlsx.ster
// est_prop__S0285_S0287_by_elementary_shell_MIxlsx.ster
// est_prop__S0285_S0287_by_elementary_shell_SVY_MIxlsx.ster
// est_prop__S0285_S0287_by_elementary_shell_SVYxlsx.ster
// est_prop__S0285_S0287_by_elementary_shellxlsx.ster
// est_prop__S0285_S0287_by_secondary_shell_MIxlsx.ster
// est_prop__S0285_S0287_by_secondary_shell_SVY_MIxlsx.ster
// est_prop__S0285_S0287_by_secondary_shell_SVYxlsx.ster
// est_prop__S0285_S0287_by_secondary_shellxlsx.ster
// est_prop__T0104_rc_by_all_shell_SVYxlsx.ster
// est_prop__T0104_rc_by_all_shellxlsx.ster
// est_prop__T0104_rc_by_elementary_shell_SVYxlsx.ster
// est_prop__T0104_rc_by_elementary_shellxlsx.ster
// est_prop__T0104_rc_by_secondary_shell_SVYxlsx.ster
// est_prop__T0104_rc_by_secondary_shellxlsx.ster
// est_prop__T0104_rc_miss_by_all_shell_MIxlsx.ster
// est_prop__T0104_rc_miss_by_all_shell_SVY_MIxlsx.ster
// est_prop__T0104_rc_miss_by_elementary_shell_MIxlsx.ster
// est_prop__T0104_rc_miss_by_elementary_shell_SVY_MIxlsx.ster
// est_prop__T0104_rc_miss_by_secondary_shell_MIxlsx.ster
// est_prop__T0104_rc_miss_by_secondary_shell_SVY_MIxlsx.ster
// est_prop__T0356_by_all_shell_MIxlsx.ster
// est_prop__T0356_by_all_shell_SVY_MIxlsx.ster
// est_prop__T0356_by_all_shell_SVYxlsx.ster
// est_prop__T0356_by_all_shellxlsx.ster
// est_prop__T0356_by_elementary_shell_MIxlsx.ster
// est_prop__T0356_by_elementary_shell_SVY_MIxlsx.ster
// est_prop__T0356_by_elementary_shell_SVYxlsx.ster
// est_prop__T0356_by_elementary_shellxlsx.ster
// est_prop__T0356_by_secondary_shell_MIxlsx.ster
// est_prop__T0356_by_secondary_shell_SVY_MIxlsx.ster
// est_prop__T0356_by_secondary_shell_SVYxlsx.ster
// est_prop__T0356_by_secondary_shellxlsx.ster
// est_prop__TOTEXPER_rc_by_all_shell_SVYxlsx.ster
// est_prop__TOTEXPER_rc_by_all_shellxlsx.ster
// est_prop__TOTEXPER_rc_by_elementary_shell_SVYxlsx.ster
// est_prop__TOTEXPER_rc_by_elementary_shellxlsx.ster
// est_prop__TOTEXPER_rc_by_secondary_shell_SVYxlsx.ster
// est_prop__TOTEXPER_rc_by_secondary_shellxlsx.ster
// est_prop__TOTEXPER_rc_miss_by_all_shell_MIxlsx.ster
// est_prop__TOTEXPER_rc_miss_by_all_shell_SVY_MIxlsx.ster
// est_prop__TOTEXPER_rc_miss_by_elementary_shell_MIxlsx.ster
// est_prop__TOTEXPER_rc_miss_by_elementary_shell_SVY_MIxlsx.ster
// est_prop__TOTEXPER_rc_miss_by_secondary_shell_MIxlsx.ster
// est_prop__TOTEXPER_rc_miss_by_secondary_shell_SVY_MIxlsx.ster
// est_prop__URBANIC_by_all_shell_MIxlsx.ster
// est_prop__URBANIC_by_all_shell_SVY_MIxlsx.ster
// est_prop__URBANIC_by_all_shell_SVYxlsx.ster
// est_prop__URBANIC_by_all_shellxlsx.ster
// est_prop__URBANIC_by_elementary_shell_MIxlsx.ster
// est_prop__URBANIC_by_elementary_shell_SVY_MIxlsx.ster
// est_prop__URBANIC_by_elementary_shell_SVYxlsx.ster
// est_prop__URBANIC_by_elementary_shellxlsx.ster
// est_prop__URBANIC_by_secondary_shell_MIxlsx.ster
// est_prop__URBANIC_by_secondary_shell_SVY_MIxlsx.ster
// est_prop__URBANIC_by_secondary_shell_SVYxlsx.ster
// est_prop__URBANIC_by_secondary_shellxlsx.ster
// est_prop__all_by_elementary_shell_MIxlsx.ster
// est_prop__all_by_elementary_shell_SVY_MIxlsx.ster
// est_prop__all_by_elementary_shell_SVYxlsx.ster
// est_prop__all_by_elementary_shellxlsx.ster
// est_prop__all_by_secondary_shell_MIxlsx.ster
// est_prop__all_by_secondary_shell_SVY_MIxlsx.ster
// est_prop__all_by_secondary_shell_SVYxlsx.ster
// est_prop__all_by_secondary_shellxlsx.ster
// est_prop__all_shell_MIxlsx.ster
// est_prop__all_shell_SVY_MIxlsx.ster
// est_prop__all_shell_SVYxlsx.ster
// est_prop__all_shellxlsx.ster
// est_total_cons_by_AGE_T_all_shell_MIxlsx.ster
// est_total_cons_by_AGE_T_all_shell_SVY_MIxlsx.ster
// est_total_cons_by_AGE_T_all_shell_SVYxlsx.ster
// est_total_cons_by_AGE_T_all_shellxlsx.ster
// est_total_cons_by_AGE_T_elementary_shell_MIxlsx.ster
// est_total_cons_by_AGE_T_elementary_shell_SVY_MIxlsx.ster
// est_total_cons_by_AGE_T_elementary_shell_SVYxlsx.ster
// est_total_cons_by_AGE_T_elementary_shellxlsx.ster
// est_total_cons_by_AGE_T_secondary_shell_MIxlsx.ster
// est_total_cons_by_AGE_T_secondary_shell_SVY_MIxlsx.ster
// est_total_cons_by_AGE_T_secondary_shell_SVYxlsx.ster
// est_total_cons_by_AGE_T_secondary_shellxlsx.ster
// est_total_cons_by_Highest_degree_all_shell_MIxlsx.ster
// est_total_cons_by_Highest_degree_all_shell_SVY_MIxlsx.ster
// est_total_cons_by_Highest_degree_all_shell_SVYxlsx.ster
// est_total_cons_by_Highest_degree_all_shellxlsx.ster
// est_total_cons_by_Highest_degree_elementary_shell_MIxlsx.ster
// est_total_cons_by_Highest_degree_elementary_shell_SVY_MIxlsx.ster
// est_total_cons_by_Highest_degree_elementary_shell_SVYxlsx.ster
// est_total_cons_by_Highest_degree_elementary_shellxlsx.ster
// est_total_cons_by_Highest_degree_secondary_shell_MIxlsx.ster
// est_total_cons_by_Highest_degree_secondary_shell_SVY_MIxlsx.ster
// est_total_cons_by_Highest_degree_secondary_shell_SVYxlsx.ster
// est_total_cons_by_Highest_degree_secondary_shellxlsx.ster
// est_total_cons_by_RACETH_T_all_shell_MIxlsx.ster
// est_total_cons_by_RACETH_T_all_shell_SVY_MIxlsx.ster
// est_total_cons_by_RACETH_T_all_shell_SVYxlsx.ster
// est_total_cons_by_RACETH_T_all_shellxlsx.ster
// est_total_cons_by_RACETH_T_elementary_shell_MIxlsx.ster
// est_total_cons_by_RACETH_T_elementary_shell_SVY_MIxlsx.ster
// est_total_cons_by_RACETH_T_elementary_shell_SVYxlsx.ster
// est_total_cons_by_RACETH_T_elementary_shellxlsx.ster
// est_total_cons_by_RACETH_T_secondary_shell_MIxlsx.ster
// est_total_cons_by_RACETH_T_secondary_shell_SVY_MIxlsx.ster
// est_total_cons_by_RACETH_T_secondary_shell_SVYxlsx.ster
// est_total_cons_by_RACETH_T_secondary_shellxlsx.ster
// est_total_cons_by_S0285_S0287_all_shell_MIxlsx.ster
// est_total_cons_by_S0285_S0287_all_shell_SVY_MIxlsx.ster
// est_total_cons_by_S0285_S0287_all_shell_SVYxlsx.ster
// est_total_cons_by_S0285_S0287_all_shellxlsx.ster
// est_total_cons_by_S0285_S0287_elementary_shell_MIxlsx.ster
// est_total_cons_by_S0285_S0287_elementary_shell_SVY_MIxlsx.ster
// est_total_cons_by_S0285_S0287_elementary_shell_SVYxlsx.ster
// est_total_cons_by_S0285_S0287_elementary_shellxlsx.ster
// est_total_cons_by_S0285_S0287_secondary_shell_MIxlsx.ster
// est_total_cons_by_S0285_S0287_secondary_shell_SVY_MIxlsx.ster
// est_total_cons_by_S0285_S0287_secondary_shell_SVYxlsx.ster
// est_total_cons_by_S0285_S0287_secondary_shellxlsx.ster
// est_total_cons_by_T0104_rc_all_shell_SVYxlsx.ster
// est_total_cons_by_T0104_rc_all_shellxlsx.ster
// est_total_cons_by_T0104_rc_elementary_shell_SVYxlsx.ster
// est_total_cons_by_T0104_rc_elementary_shellxlsx.ster
// est_total_cons_by_T0104_rc_miss_all_shell_MIxlsx.ster
// est_total_cons_by_T0104_rc_miss_all_shell_SVY_MIxlsx.ster
// est_total_cons_by_T0104_rc_miss_elementary_shell_MIxlsx.ster
// est_total_cons_by_T0104_rc_miss_elementary_shell_SVY_MIxlsx.ster
// est_total_cons_by_T0104_rc_miss_secondary_shell_MIxlsx.ster
// est_total_cons_by_T0104_rc_miss_secondary_shell_SVY_MIxlsx.ster
// est_total_cons_by_T0104_rc_secondary_shell_SVYxlsx.ster
// est_total_cons_by_T0104_rc_secondary_shellxlsx.ster
// est_total_cons_by_T0356_all_shell_MIxlsx.ster
// est_total_cons_by_T0356_all_shell_SVY_MIxlsx.ster
// est_total_cons_by_T0356_all_shell_SVYxlsx.ster
// est_total_cons_by_T0356_all_shellxlsx.ster
// est_total_cons_by_T0356_elementary_shell_MIxlsx.ster
// est_total_cons_by_T0356_elementary_shell_SVY_MIxlsx.ster
// est_total_cons_by_T0356_elementary_shell_SVYxlsx.ster
// est_total_cons_by_T0356_elementary_shellxlsx.ster
// est_total_cons_by_T0356_secondary_shell_MIxlsx.ster
// est_total_cons_by_T0356_secondary_shell_SVY_MIxlsx.ster
// est_total_cons_by_T0356_secondary_shell_SVYxlsx.ster
// est_total_cons_by_T0356_secondary_shellxlsx.ster
// est_total_cons_by_TOTEXPER_rc_all_shell_SVYxlsx.ster
// est_total_cons_by_TOTEXPER_rc_all_shellxlsx.ster
// est_total_cons_by_TOTEXPER_rc_elementary_shell_SVYxlsx.ster
// est_total_cons_by_TOTEXPER_rc_elementary_shellxlsx.ster
// est_total_cons_by_TOTEXPER_rc_miss_all_shell_MIxlsx.ster
// est_total_cons_by_TOTEXPER_rc_miss_all_shell_SVY_MIxlsx.ster
// est_total_cons_by_TOTEXPER_rc_miss_elementary_shell_MIxlsx.ster
// est_total_cons_by_TOTEXPER_rc_miss_elementary_shell_SVY_MIxlsx.ster
// est_total_cons_by_TOTEXPER_rc_miss_secondary_shell_MIxlsx.ster
// est_total_cons_by_TOTEXPER_rc_miss_secondary_shell_SVY_MIxlsx.ster
// est_total_cons_by_TOTEXPER_rc_secondary_shell_SVYxlsx.ster
// est_total_cons_by_TOTEXPER_rc_secondary_shellxlsx.ster
// est_total_cons_by_URBANIC_all_shell_MIxlsx.ster
// est_total_cons_by_URBANIC_all_shell_SVY_MIxlsx.ster
// est_total_cons_by_URBANIC_all_shell_SVYxlsx.ster
// est_total_cons_by_URBANIC_all_shellxlsx.ster
// est_total_cons_by_URBANIC_elementary_shell_MIxlsx.ster
// est_total_cons_by_URBANIC_elementary_shell_SVY_MIxlsx.ster
// est_total_cons_by_URBANIC_elementary_shell_SVYxlsx.ster
// est_total_cons_by_URBANIC_elementary_shellxlsx.ster
// est_total_cons_by_URBANIC_secondary_shell_MIxlsx.ster
// est_total_cons_by_URBANIC_secondary_shell_SVY_MIxlsx.ster
// est_total_cons_by_URBANIC_secondary_shell_SVYxlsx.ster
// est_total_cons_by_URBANIC_secondary_shellxlsx.ster
// est_total_cons_by_all_elementary_shell_MIxlsx.ster
// est_total_cons_by_all_elementary_shell_SVY_MIxlsx.ster
// est_total_cons_by_all_elementary_shell_SVYxlsx.ster
// est_total_cons_by_all_elementary_shellxlsx.ster
// est_total_cons_by_all_secondary_shell_MIxlsx.ster
// est_total_cons_by_all_secondary_shell_SVY_MIxlsx.ster
// est_total_cons_by_all_secondary_shell_SVYxlsx.ster
// est_total_cons_by_all_secondary_shellxlsx.ster
// est_total_cons_by_all_shell_MIxlsx.ster
// est_total_cons_by_all_shell_SVY_MIxlsx.ster
// est_total_cons_by_all_shell_SVYxlsx.ster
// est_total_cons_by_all_shellxlsx.ster
// shell_MI_populated.xlsx
// shell_SVY_MI_populated.xlsx
// shell_SVY_populated.xlsx
// shell_populated.xlsx
// table_estimates_shell_MIxlsx.dta
// table_estimates_shell_SVY_MIxlsx.dta
// table_estimates_shell_SVYxlsx.dta
// table_estimates_shellxlsx.dta
